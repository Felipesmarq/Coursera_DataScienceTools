# %% [markdown]
# <a href="https://colab.research.google.com/github/Felipesmarq/Coursera_DataScienceTools/blob/main/AnaliseF1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile

with zipfile.ZipFile("/archive (1).zip", "r") as zip_ref:
  zip_ref.extractall("dataset")

# %%
import pandas as pd

df_race = pd.read_csv("/content/dataset/AllRace.csv")
df_cs = pd.read_csv("/content/dataset/ConstructorStandings.csv")
df_ds = pd.read_csv("/content/dataset/DriversStandings.csv")

# %% [markdown]
# # datasets
#
# ### race - All race informations
# ### cs - Constructor Standings
# ### ds - Drivers Standings
#
# ## The data is from 1950-2020.

# %% [markdown]
# #### In the race data frame contains the name of the race(where it occurred), date of the race and all drivers standings

# %%
df_race.head()
# Out:
#          Unnamed: 0       Date                       1                   2  \
# 0     Great Britain  13-May-50         Nino Farina FAR   Luigi Fagioli FAG
# 1            Monaco  21-May-50  Juan Manuel Fangio FAN  Alberto Ascari ASC
# 2  Indianapolis 500  30-May-50     Johnnie Parsons PAR    Bill Holland HOL
# 3       Switzerland  04-Jun-50         Nino Farina FAR   Luigi Fagioli FAG
# 4           Belgium  18-Jun-50  Juan Manuel Fangio FAN   Luigi Fagioli FAG
#
#                   3                          4                   5  \
# 0   Reg Parnell PAR  Yves Giraud Cabantous CAB    Louis Rosier ROS
# 1  Louis Chiron CHI         Raymond Sommer SOM     Prince Bira BIR
# 2    Mauri Rose ROS            Cecil Green GRE   Joie Chitwood CHI
# 3  Louis Rosier ROS            Prince Bira BIR  Felice Bonetto BON
# 4  Louis Rosier ROS            Nino Farina FAR  Alberto Ascari ASC
#
#                           6                  7                       8  ...  \
# 0            Bob Gerard GER  Cuth Harrison HAR  Philippe Etancelin ETA  ...
# 1            Bob Gerard GER   Johnny Claes CLA     Luigi Villoresi VIL  ...
# 2     Tony Bettenhausen BET    Lee Wallard WAL       Walt Faulkner FAU  ...
# 3  Toulo de Graffenried DEG   Nello Pagani PAG        Harry Schell SCH  ...
# 4       Luigi Villoresi VIL  Pierre Levegh LEV        Johnny Claes CLA  ...
#
#                 26                   27                  28  \
# 0              NaN                  NaN                 NaN
# 1              NaN                  NaN                 NaN
# 2  Henry Banks BAN  Fred Agabashian AGA  Bill Schindler SCH
# 3              NaN                  NaN                 NaN
# 4              NaN                  NaN                 NaN
#
#                     29                 30                 31             32  \
# 0                  NaN                NaN                NaN            NaN
# 1                  NaN                NaN                NaN            NaN
# 2  Bayliss Levrett LEV  Bill Cantrell CAN  Jimmy Jackson JAC  Sam Hanks HAN
# 3                  NaN                NaN                NaN            NaN
# 4                  NaN                NaN                NaN            NaN
#
#                   33                 34   35
# 0                NaN                NaN  NaN
# 1                NaN                NaN  NaN
# 2  Dick Rathmann RAT  Duke Dinsmore DIN  NaN
# 3                NaN                NaN  NaN
# 4                NaN                NaN  NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# ####In the Constructor Standings dataset, each line contains the position, name of the team, points made by that team and the year.

# %%
df_cs.head()
# Out:
#    Unnamed: 0 Pos           Team  PTS  Year
# 0           0   1        Vanwall   48  1958
# 1           1   2        Ferrari   40  1958
# 2           2   3  Cooper Climax   31  1958
# 3           3   4            BRM   18  1958
# 4           4   5       Maserati    6  1958

# %% [markdown]
# #### The Drivers Standings compiles in each line the position of the driver, have the name of the driver(with 3 letters that represent the name of the driver), nacionality, car, points made in the year and the year

# %%
df_ds
# Out:
#       Unnamed: 0 Pos                  Driver Nationality  \
# 0              0   1         Nino Farina FAR         ITA
# 1              1   2  Juan Manuel Fangio FAN         ARG
# 2              2   3       Luigi Fagioli FAG         ITA
# 3              3   4        Louis Rosier ROS         FRA
# 4              4   5      Alberto Ascari ASC         ITA
# ...          ...  ..                     ...         ...
# 1568        1568  17     Kevin Magnussen MAG         DEN
# 1569        1569  18      Kimi Räikkönen RAI         FIN
# 1570        1570  19     Nicholas Latifi LAT         CAN
# 1571        1571  20      George Russell RUS         GBR
# 1572        1572  21     Romain Grosjean GRO         FRA
#
#                             Car   PTS  Year
# 0                    Alfa Romeo  30.0  1950
# 1                    Alfa Romeo  27.0  1950
# 2                    Alfa Romeo  24.0  1950
# 3                   Talbot-Lago  13.0  1950
# 4                       Ferrari  11.0  1950
# ...                         ...   ...   ...
# 1568               Haas Ferrari   1.0  2020
# 1569  Alfa Romeo Racing Ferrari   0.0  2020
# 1570          Williams Mercedes   0.0  2020
# 1571          Williams Mercedes   0.0  2020
# 1572               Haas Ferrari   0.0  2020
#
# [1573 rows x 7 columns]

# %%
posicoes = [str(i) for i in range(1, 36)]

pilotos = df_race[posicoes].values.flatten()

pilotos_series = pd.Series(pilotos).dropna()

participacoes = pilotos_series.value_counts().reset_index()

participacoes.columns = ["Corredor", "Corridas"]

corridas = df_race.shape[0]

participacoes["% Participações"] = (participacoes["Corridas"] / corridas * 100).round(2)

participacoes.head(10)
# Out:
#                  Corredor  Corridas  % Participações
# 0    Kimi RÃ¤ikkÃ¶nen RAI       319            31.12
# 1  Rubens Barrichello BAR       316            30.83
# 2     Fernando Alonso ALO       310            30.24
# 3       Jenson Button BUT       302            29.46
# 4  Michael Schumacher MSC       297            28.98
# 5        Felipe Massa MAS       265            25.85
# 6      Lewis Hamilton HAM       254            24.78
# 7        Jarno Trulli TRU       252            24.59
# 8    Riccardo Patrese PAT       248            24.20
# 9     David Coulthard COU       245            23.90

# %%
podio = ["1", "2", "3"]

pilotos_podio = pd.Series(df_race[podio].values.flatten()).dropna()

df_podios = pilotos_podio.value_counts().reset_index()

df_podios.columns = ["Corredor", "Podios"]

df_podios["% Podios"] = (df_podios["Podios"] / corridas * 100).round(2)

df_podios.head(10)
# Out:
#                  Corredor  Podios  % Podios
# 0      Lewis Hamilton HAM     156     15.22
# 1  Michael Schumacher MSC     153     14.93
# 2    Sebastian Vettel VET     118     11.51
# 3         Alain Prost PRO     106     10.34
# 4    Kimi RÃ¤ikkÃ¶nen RAI     102      9.95
# 5     Fernando Alonso ALO      96      9.37
# 6        Ayrton Senna SEN      79      7.71
# 7  Rubens Barrichello BAR      67      6.54
# 8     David Coulthard COU      62      6.05
# 9       Nelson Piquet PIQ      60      5.85
